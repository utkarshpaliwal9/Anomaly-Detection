# %% [markdown]
# <a href="https://colab.research.google.com/github/utkarshpaliwal9/Anomaly-Detection/blob/master/Major_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !wget 'https://ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com/cd/0/get/AwnTshqOOPemhrjTqZXlfp02PCkgNJSJt8jhllVUuRTJn90nr_5blsJzj0JrrIDnpQ2lApMyJKY3KTi_4saPTdvB3611txsv82RztoOYS5GARg/file?_download_id=011006157493155033421613254309845225599327459049660434941660553837&_notify_domain=www.dropbox.com&dl=1'
# Out:
# --2020-01-21 12:36:49--  https://ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com/cd/0/get/AwnTshqOOPemhrjTqZXlfp02PCkgNJSJt8jhllVUuRTJn90nr_5blsJzj0JrrIDnpQ2lApMyJKY3KTi_4saPTdvB3611txsv82RztoOYS5GARg/file?_download_id=011006157493155033421613254309845225599327459049660434941660553837&_notify_domain=www.dropbox.com&dl=1
# Resolving ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com (ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com (ucb7dca99505e76e54fa172ef606.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6693096368 (6.2G) [application/binary]
# Saving to: ‘file?_download_id=011006157493155033421613254309845225599327459049660434941660553837&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=0 100%[===================>]   6.23G  13.8MB/s    in 2m 50s
#
# ...

# %%
#rename

# %%
!7z x '/content/anomaly_part2.zip'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 6693096368 bytes (6384 MiB)
#
# Extracting archive: /content/anomaly_part2.zip
# --
# Path = /content/anomaly_part2.zip
# Type = zip
# Physical Size = 6693096368
# 64-bit = +
#
#   0%
# Would you like to replace the existing file:
#   Path:     ./Anomaly-Videos-Part-2/Burglary/Burglary063_x264.mp4
#   Size:     18327319 bytes (18 MiB)
#   Modified: 2017-04-10 17:05:25
# with the file from archive:
#   Path:     Anomaly-Videos-Part-2/Burglary/Burglary063_x264.mp4
#   Size:     18327319 bytes (18 MiB)
#   Modified: 2017-04-10 17:05:25
# ? (Y)es / (N)o / (A)lways / (S)kip all / A(u)to rename all / (Q)uit?

# %%
# !mv '/content/Anomaly-Videos-Part-2' '/content/drive/My Drive/Project/'

# %%
# !wget "https://uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com/cd/0/get/AwMS2jll2ZsP5gXt8WYNIgJbnEJbN2IDPlt7i8s3RE2wvZ-MLknoXSxdI4SY68PjsyuZeJ8hS4_Umu0YG5A6t8qnf7FDiE5NbOwLTKR9m-Op5A/file?_download_id=26842697584487140544307203506444460731291696667291107310867088734785&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-15 13:40:39--  https://uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com/cd/0/get/AwMS2jll2ZsP5gXt8WYNIgJbnEJbN2IDPlt7i8s3RE2wvZ-MLknoXSxdI4SY68PjsyuZeJ8hS4_Umu0YG5A6t8qnf7FDiE5NbOwLTKR9m-Op5A/file?_download_id=26842697584487140544307203506444460731291696667291107310867088734785&_notify_domain=www.dropbox.com&dl=1
# Resolving uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com (uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com)... 162.125.1.6, 2620:100:6016:6::a27d:106
# Connecting to uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com (uc56f5099bb273efb6ae5f378ae8.dl.dropboxusercontent.com)|162.125.1.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70394 (69K) [application/binary]
# Saving to: ‘file?_download_id=26842697584487140544307203506444460731291696667291107310867088734785&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=2 100%[===================>]  68.74K  --.-KB/s    in 0.01s
#
# ...

# %%
# !wget --no-check-certificate "https://uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com/cd/0/get/AwOMV7HYB99EP3qJfiNjSPSS6XXB-FMWrLF4m3MJdBo_0-XUlCCxZTgjA82ko__EvSyFv5CdudBGGSibF9XRYWQfe-D1VnlNTda562xwH1IHww/file?_download_id=506935986253414526729073992478660161518623505098054952831654550397&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-15 13:57:47--  https://uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com/cd/0/get/AwOMV7HYB99EP3qJfiNjSPSS6XXB-FMWrLF4m3MJdBo_0-XUlCCxZTgjA82ko__EvSyFv5CdudBGGSibF9XRYWQfe-D1VnlNTda562xwH1IHww/file?_download_id=506935986253414526729073992478660161518623505098054952831654550397&_notify_domain=www.dropbox.com&dl=1
# Resolving uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com (uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com)... 162.125.1.6, 2620:100:601b:6::a27d:806
# Connecting to uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com (uc50213ee5ba4f5b53184877b462.dl.dropboxusercontent.com)|162.125.1.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6272044173 (5.8G) [application/binary]
# Saving to: ‘file?_download_id=506935986253414526729073992478660161518623505098054952831654550397&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=5  19%[==>                 ]   1.15G   328KB/s    in 90s
#
# ...

# %%
# !wget --no-check-certificate "https://uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com/cd/0/get/AwP1ZZq4MZP3D4_Qmd0bKaDgOnn1E_08Q59OciHYoavjk1pBc8cGbrlcZrbEkasy0ZNlY9pjMBoIe60x-SYEhPiQnCnP6yvc1AMW1ixcSjWiyA/file?_download_id=227332736045446681711471496235872421701305790600816212777490604019&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-15 16:01:26--  https://uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com/cd/0/get/AwP1ZZq4MZP3D4_Qmd0bKaDgOnn1E_08Q59OciHYoavjk1pBc8cGbrlcZrbEkasy0ZNlY9pjMBoIe60x-SYEhPiQnCnP6yvc1AMW1ixcSjWiyA/file?_download_id=227332736045446681711471496235872421701305790600816212777490604019&_notify_domain=www.dropbox.com&dl=1
# Resolving uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com (uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com (uc35d8e1ab645d362f5e62baef07.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6693096368 (6.2G) [application/binary]
# Saving to: ‘file?_download_id=227332736045446681711471496235872421701305790600816212777490604019&_notify_domain=www.dropbox.com&dl=1.1’
#
# file?_download_id=2 100%[===================>]   6.23G  33.1MB/s    in 4m 7s
#
# ...

# %%
# !wget "https://uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com/cd/0/get/AwOK07zn2vhdSuuP42CCOHMn4Xrd4DWjeoD13ul1CI6BMfeqh3UhrSlUfQoimfJx44F4xlBhhAOGS2VrJNbUN9qI1p1c3N9R0qzcvpSmcb2KHA/file?_download_id=41246243229563876909263183277312253646512224200655360698624314548&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-15 19:21:04--  https://uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com/cd/0/get/AwOK07zn2vhdSuuP42CCOHMn4Xrd4DWjeoD13ul1CI6BMfeqh3UhrSlUfQoimfJx44F4xlBhhAOGS2VrJNbUN9qI1p1c3N9R0qzcvpSmcb2KHA/file?_download_id=41246243229563876909263183277312253646512224200655360698624314548&_notify_domain=www.dropbox.com&dl=1
# Resolving uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com (uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com)... 162.125.1.6, 2620:100:6016:6::a27d:106
# Connecting to uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com (uc2a897141eb02365a41bcc45e32.dl.dropboxusercontent.com)|162.125.1.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38072348701 (35G) [application/binary]
# Saving to: ‘file?_download_id=41246243229563876909263183277312253646512224200655360698624314548&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=4  37%[======>             ]  13.23G  --.-KB/s    in 14m 46s
#
# ...

# %%
#36GB Normal videos data set part 1
# !wget --no-check-certificate "https://uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com/cd/0/get/AxN6nrcUpWy26pYwE9-_UyHSdi3qCVLad3EwHALhj5zKXVWo0WA0TWQUv_sGz7BivILUFNuI6PMk61_ZMPzWtQ8KmqM5XSQat6SQwCgW_u_oRg/file?_download_id=55085948185673160583929983484178242629182912885331723736351016027146&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-31 05:50:33--  https://uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com/cd/0/get/AxN6nrcUpWy26pYwE9-_UyHSdi3qCVLad3EwHALhj5zKXVWo0WA0TWQUv_sGz7BivILUFNuI6PMk61_ZMPzWtQ8KmqM5XSQat6SQwCgW_u_oRg/file?_download_id=55085948185673160583929983484178242629182912885331723736351016027146&_notify_domain=www.dropbox.com&dl=1
# Resolving uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com (uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com (uc4f1c462c83a56d74bb888e032e.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38072348701 (35G) [application/binary]
# Saving to: ‘file?_download_id=55085948185673160583929983484178242629182912885331723736351016027146&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=5 100%[===================>]  35.46G  33.4MB/s    in 22m 1s
#
# ...

# %%
#31GB Normal videos data set part 1
# !wget --no-check-certificate "https://ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com/cd/0/get/AwT8qka5fpKNAK5zMaIHmhjqTksCUZKKjua1-wmRZ5mtPKmq44MSKfAUmY8LYe5LQpN972oDnO5UJ9_opz65V7Yr0ztedhZLL6_75Pd42F0-pA/file?_download_id=8354100175894763428923212063002262699951843321767603818565431892&_notify_domain=www.dropbox.com&dl=1"
# Out:
# --2020-01-16 10:20:04--  https://ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com/cd/0/get/AwT8qka5fpKNAK5zMaIHmhjqTksCUZKKjua1-wmRZ5mtPKmq44MSKfAUmY8LYe5LQpN972oDnO5UJ9_opz65V7Yr0ztedhZLL6_75Pd42F0-pA/file?_download_id=8354100175894763428923212063002262699951843321767603818565431892&_notify_domain=www.dropbox.com&dl=1
# Resolving ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com (ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com (ucf2bde8595e5846efd7dee020f4.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34019840040 (32G) [application/binary]
# Saving to: ‘file?_download_id=8354100175894763428923212063002262699951843321767603818565431892&_notify_domain=www.dropbox.com&dl=1’
#
# main=www.dropbox.co  20%[===>                ]   6.44G  3.20MB/s    eta 15m 35s^C

# %%
import torch
from torch.autograd import variable
import cv2
#import data
import imageio

# %%
# !cp '/content/drive/My Drive/Colab Notebooks/anomaly_videos1' anomaly_videos1

# %%
with open('/content/drive/My Drive/Colab Notebooks/anomaly_videos1', 'w') as anomaly_videos1:
  # !unzip anomaly_videos1
# Out:
# Archive:  anomaly_videos1
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of anomaly_videos1 or
#         anomaly_videos1.zip, and cannot find anomaly_videos1.ZIP, period.

# %%
# !cp '/content/drive/My Drive/010 Welcome to the Practical Applications.rar' skjb

# %%
# !wget "/content/drive/My Drive/010 Welcome to the Practical Applications.rar"
# Out:
# /content/drive/My Drive/010 Welcome to the Practical Applications.rar: Scheme missing.

# %%
with open('/content/drive/My Drive/010 Welcome to the Practical Applications.rar', 'w') as skjb:
  # !unzip skjb
# Out:
# Archive:  skjb
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of skjb or
#         skjb.zip, and cannot find skjb.ZIP, period.

# %%
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 0 bytes
#
# Extracting archive: /content/drive/My Drive/Colab Notebooks/normal_videos_only_6_gb
# ERROR: /content/drive/My Drive/Colab Notebooks/normal_videos_only_6_gb
# Can not open the file as archive
#
#   0%
# Can't open as archive: 1
# Files: 0
# Size:       0
# Compressed: 0

# %%
# !wget 'https://uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com/cd/0/get/AwmF1_jxn1Wlju9V0_7bri9EphmX3jmj0YdstZ7l7IcroDDurpzGRD1z4eMc7nXmYJ0BiQ76AV0M48Vn7vAGh2mda4GirQfEmIvT8A10rVGTTA/file?_download_id=3075861070405364600304272134853877944827258093323949524327579604570737&_notify_domain=www.dropbox.com&dl=1' -O '/content/Normal_Videos_for_Event_Recognition.zip'
# Out:
# --2020-01-21 12:51:53--  https://uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com/cd/0/get/AwmF1_jxn1Wlju9V0_7bri9EphmX3jmj0YdstZ7l7IcroDDurpzGRD1z4eMc7nXmYJ0BiQ76AV0M48Vn7vAGh2mda4GirQfEmIvT8A10rVGTTA/file?_download_id=3075861070405364600304272134853877944827258093323949524327579604570737&_notify_domain=www.dropbox.com&dl=1
# Resolving uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com (uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com)... 162.125.9.6, 2620:100:601f:6::a27d:906
# Connecting to uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com (uca2ac48eea241bfda7bfba55fd1.dl.dropboxusercontent.com)|162.125.9.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1074742914 (1.0G) [application/binary]
# Saving to: ‘/content/Normal_Videos_for_Event_Recognition.zip’
#
# /content/Normal_Vid 100%[===================>]   1.00G  41.9MB/s    in 29s
#
# ...

# %%
!7z x '/content/Normal_Videos_for_Event_Recognition.zip' -o'/content/drive/My Drive/Project'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1074742914 bytes (1025 MiB)
#
# Extracting archive: /content/Normal_Videos_for_Event_Recognition.zip
# --
# Path = /content/Normal_Videos_for_Event_Recognition.zip
# Type = zip
# Physical Size = 1074742914
#
# Everything is Ok
#
# Folders: 1
# Files: 50
# Size:       1092909264
# Compressed: 1074742914

# %%
# !rm -rf '/content/Anomaly-Videos-Part-2'

# %%
# !apt install aria2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libc-ares2
# The following NEW packages will be installed:
#   aria2 libc-ares2
# 0 upgraded, 2 newly installed, 0 to remove and 7 not upgraded.
# Need to get 1,274 kB of archives.
# After this operation, 4,912 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libc-ares2 amd64 1.14.0-1 [37.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 aria2 amd64 1.33.1-1 [1,236 kB]
# Fetched 1,274 kB in 1s (1,624 kB/s)
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 135004 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.14.0-1_amd64.deb ...
# ...

# %%
# !aria2c -x 16 'https://uc16a9f6818b3bd516d064fd586e.dl.dropboxusercontent.com/cd/0/get/AwktJqWzZ33CTlSr4I05e1UibgdL6YUKOuJz8y3w3PAfx8fVM5daZ3WnZlu-L9vcgMAXgLJps_Q7a6yWzeDuAnrS3xqwFJ0u_rmZt_xoi7Adjg/file?_download_id=5268824845635661750661574931996359704770274683935301367897055752&_notify_domain=www.dropbox.com&dl=1' -o '/content/Training-Normal-Videos-Part-1.zip'
# Out:
# 01/21 13:00:38 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Tue Jan 21 13:01:39 2020 ***
# =
# [#d8ca5a 4.4GiB/35GiB(12%) CN:5 DL:60MiB ETA:8m46s]
# FILE: /content//content/Training-Normal-Videos-Part-1.zip
# -
#
#  *** Download Progress Summary as of Tue Jan 21 13:02:40 2020 ***
# =
# [#d8ca5a 7.8GiB/35GiB(22%) CN:5 DL:50MiB ETA:9m22s]
# FILE: /content//content/Training-Normal-Videos-Part-1.zip
# -
#
#  *** Download Progress Summary as of Tue Jan 21 13:03:40 2020 ***
# =
# [#d8ca5a 11GiB/35GiB(31%) CN:5 DL:57MiB ETA:7m8s]
# FILE: /content//content/Training-Normal-Videos-Part-1.zip
# -
#
#  *** Download Progress Summary as of Tue Jan 21 13:04:41 2020 ***
# =
# [#d8ca5a 14GiB/35GiB(41%) CN:5 DL:59MiB ETA:5m58s]
# FILE: /content//content/Training-Normal-Videos-Part-1.zip
# -
#
#  *** Download Progress Summary as of Tue Jan 21 13:05:42 2020 ***
# =
# [#d8ca5a 18GiB/35GiB(51%) CN:5 DL:59MiB ETA:4m58s]
# FILE: /content//content/Training-Normal-Videos-Part-1.zip
# ...

# %%
!7z x '/content/content/Training-Normal-Videos-Part-1.zip' -o'/content/drive/My Drive/Project'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 38072348701 bytes (36 GiB)
#
# Extracting archive: /content/content/Training-Normal-Videos-Part-1.zip
# --
# Path = /content/content/Training-Normal-Videos-Part-1.zip
# Type = zip
# Physical Size = 38072348701
# 64-bit = +
#
# Everything is Ok
#
# Folders: 1
# Files: 430
# Size:       38621578867
# Compressed: 38072348701

# %%
# !wget 'https://ucfa0064536021facc523f627b68.dl.dropboxusercontent.com/cd/0/get/AxLVx2JBJGLWq-bvJBDnXl3iQNSsXbEcAISxUr5ycji21eosDZgyTdClH7cXUpwf04paqYYeHACmELpUil3Aw7aHckNbzL4G_4LTbZS5wE88RA/file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1'
# Out:
# --2020-01-30 19:30:39--  https://ucfa0064536021facc523f627b68.dl.dropboxusercontent.com/cd/0/get/AxLVx2JBJGLWq-bvJBDnXl3iQNSsXbEcAISxUr5ycji21eosDZgyTdClH7cXUpwf04paqYYeHACmELpUil3Aw7aHckNbzL4G_4LTbZS5wE88RA/file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1
# Resolving ucfa0064536021facc523f627b68.dl.dropboxusercontent.com (ucfa0064536021facc523f627b68.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to ucfa0064536021facc523f627b68.dl.dropboxusercontent.com (ucfa0064536021facc523f627b68.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5616615706 (5.2G) [application/binary]
# Saving to: ‘file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1’
#
# file?_download_id=8 100%[===================>]   5.23G  31.1MB/s    in 2m 41s
#
# ...

# %%
!7z x '/content/file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 5616615706 bytes (5357 MiB)
#
# Extracting archive: /content/file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1
# --
# Path = /content/file?_download_id=8733156507545082410608043002890969093567009102712345234271902494&_notify_domain=www.dropbox.com&dl=1
# Type = zip
# Physical Size = 5616615706
# 64-bit = +
#
# Everything is Ok
#
# Folders: 4
# Files: 350
# Size:       5749304865
# Compressed: 5616615706

# %%
#Downloading Darkflow
# !wget "https://codeload.github.com/thtrieu/darkflow/zip/master"
# Out:
# --2020-01-31 18:01:41--  https://codeload.github.com/thtrieu/darkflow/zip/master
# Resolving codeload.github.com (codeload.github.com)... 192.30.253.120
# Connecting to codeload.github.com (codeload.github.com)|192.30.253.120|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master’
#
# master                  [   <=>              ]  16.43M  19.6MB/s    in 0.8s
#
# 2020-01-31 18:01:42 (19.6 MB/s) - ‘master’ saved [17229328]

# %%
!7z x '/content/master'
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 17229328 bytes (17 MiB)
#
# Extracting archive: /content/master
# --
# Path = /content/master
# Type = zip
# Physical Size = 17229328
# Comment = b2aee0000cd2a956b9f1de6dbfef94d53158b7d8
#
# Everything is Ok
#
# Folders: 19
# Files: 90
# Size:       17421767
# Compressed: 17229328

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/darkflow-master')

# %%
# !wget 'https://pjreddie.com/media/files/yolov2-voc.weights'
# Out:
# --2020-01-31 18:25:14--  https://pjreddie.com/media/files/yolov2-voc.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 202704264 (193M) [application/octet-stream]
# Saving to: ‘yolov2-voc.weights’
#
# yolov2-voc.weights  100%[===================>] 193.31M  61.9MB/s    in 3.3s
#
# 2020-01-31 18:25:18 (58.8 MB/s) - ‘yolov2-voc.weights’ saved [202704264/202704264]

# %%
#voc weights
# !wget 'https://pjreddie.com/media/files/yolov2.weights'
# Out:
# --2020-01-31 19:15:38--  https://pjreddie.com/media/files/yolov2.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203934260 (194M) [application/octet-stream]
# Saving to: ‘yolov2.weights’
#
# yolov2.weights      100%[===================>] 194.49M  65.1MB/s    in 3.0s
#
# 2020-01-31 19:15:41 (65.1 MB/s) - ‘yolov2.weights’ saved [203934260/203934260]

# %%
mkdir bin

# %%
# !mv '/content/darkflow-master/yolov2-voc.weights' '/content/darkflow-master/bin'

# %%
# !pip install .
# Out:
# Processing /content/darkflow-master
# ...
#   Created wheel for darkflow: filename=darkflow-1.0.0-cp36-cp36m-linux_x86_64.whl size=830345 sha256=5976d84711b7f3815f66c9ed5108bcaba9da501468b03f0babef38e6d9be1b9f
#   Stored in directory: /root/.cache/pip/wheels/94/cd/45/fe842f09b1dc09b90a7b34f82e86d34db8978db075b9e3c173
# Successfully built darkflow
# ...

# %%
# %load_ext Cython

# %%
# %%cython
#
# cdef int a = 0
# for i in range(10):
#     a += i
# print(a)
# Out:
# 45

# %%
# %%cython --annotate
# ...
# Out:
# <!DOCTYPE html>
# <!-- Generated by Cython 0.29.14 -->
# <html>
# <head>
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <title>Cython: _cython_magic_0f1226829a0c63f08a90314ecda6ce0a.pyx</title>
#     <style type="text/css">
#
# body.cython { font-family: courier; font-size: 12; }
#
# .cython.tag  {  }
# .cython.line { margin: 0em }
# .cython.code { font-size: 9; color: #444444; display: none; margin: 0px 0px 0px 8px; border-left: 8px none; }
#
# .cython.line .run { background-color: #B0FFB0; }
# .cython.line .mis { background-color: #FFB0B0; }
# .cython.code.run  { border-left: 8px solid #B0FFB0; }
# .cython.code.mis  { border-left: 8px solid #FFB0B0; }
#
# .cython.code .py_c_api  { color: red; }
# .cython.code .py_macro_api  { color: #FF7000; }
# .cython.code .pyx_c_api  { color: #FF3000; }
# .cython.code .pyx_macro_api  { color: #FF7000; }
# .cython.code .refnanny  { color: #FFA000; }
# .cython.code .trace  { color: #FFA000; }
# ...

# %%
# !cd ./cython_utils
# !python3 setup.py build_ext --inplace
# !cd ..
# Out:
# /bin/bash: line 0: cd: ./cython_utils: No such file or directory
# Compiling darkflow/cython_utils/nms.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo2_findboxes.pyx because it changed.
# Compiling darkflow/cython_utils/cy_yolo_findboxes.pyx because it changed.
# [1/3] Cythonizing darkflow/cython_utils/cy_yolo2_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/darkflow-master/darkflow/cython_utils/cy_yolo2_findboxes.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# [2/3] Cythonizing darkflow/cython_utils/cy_yolo_findboxes.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/darkflow-master/darkflow/cython_utils/cy_yolo_findboxes.pyx
# ...

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/darkflow-master')
import cv2
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# ...

# %%
options = {
 'model': 'cfg/yolo.cfg',
 'load': 'bin/yolov2.weights',
 'threshold': 0.3
}
tfnet = TFNet(options)
# Out:
# /content/drive/My Drive/Colab Notebooks/darkflow-master/darkflow/dark/darknet.py:54: UserWarning: ./cfg/yolov2.cfg not found, use cfg/yolo.cfg instead
#   cfg_path, FLAGS.model))
# Parsing cfg/yolo.cfg
# Loading bin/yolov2.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.34125828742980957s
# Model has a coco model name, loading coco labels.
#
# Building net ...
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/darkflow-master/darkflow/net/build.py:105: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
# WARNING:tensorflow:From /content/drive/My Drive/Colab Notebooks/darkflow-master/darkflow/net/ops/baseop.py:70: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
img = cv2.imread('/content/drive/My Drive/Harmful Images/knife blade.png', cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# use YOLO to predict the image
result = tfnet.return_predict(img)

# %%
# pull out some info from the results
for i in range(0, len(result)):
    tl = (result[i]['topleft']['x'], result[i]['topleft']['y'])
    br = (result[i]['bottomright']['x'], result[i]['bottomright']['y'])
    label = result[i]['label']
# add the box and label and display it
    img = cv2.rectangle(img, tl, br, (0, 255, 0), 7)
    img = cv2.putText(img, label, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
    plt.imshow(img)
plt.show()

# %%
def detect(img):
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  # use YOLO to predict the image
  result = tfnet.return_predict(img)
  print((result[i]['topleft']['x'], result[i]['topleft']['y']))
  for i in range(0, len(result)):
    tl = (result[i]['topleft']['x'], result[i]['topleft']['y'])
    br = (result[i]['bottomright']['x'], result[i]['bottomright']['y'])
    label = result[i]['label']
  # add the box and label and display it
  img = cv2.rectangle(img, tl, br, (0, 255, 0), 7)
  img = cv2.putText(img, label, tl, cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 0), 2)
  plt.imshow(img)
  plt.show()

# %%
img = cv2.imread('/content/drive/My Drive/Harmful Images/Demon-Killing_Knife.jpg', cv2.IMREAD_COLOR)
detect(img)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-24-64911ac0d2a5> in <module>()
#       1 img = cv2.imread('/content/drive/My Drive/Harmful Images/Demon-Killing_Knife.jpg', cv2.IMREAD_COLOR)
# ----> 2 detect(img)
#
# <ipython-input-23-0f39a88065ef> in detect(img)
#       3   # use YOLO to predict the image
#       4   result = tfnet.return_predict(img)
# ----> 5   print((result[i]['topleft']['x'], result[i]['topleft']['y']))
#       6   for i in range(0, len(result)):
#       7     tl = (result[i]['topleft']['x'], result[i]['topleft']['y'])
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %%
# Tube Extraction Annotations
# !wget 'imagelab.ing.unimore.it/anomaly_locality/UCFCrime2Local.zip'
!7z x '/content/UCFCrime2Local.zip'
# Out:
# --2020-02-02 18:51:25--  http://imagelab.ing.unimore.it/anomaly_locality/UCFCrime2Local.zip
# Resolving imagelab.ing.unimore.it (imagelab.ing.unimore.it)... 155.185.48.35
# Connecting to imagelab.ing.unimore.it (imagelab.ing.unimore.it)|155.185.48.35|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 527704 (515K) [application/x-zip-compressed]
# Saving to: ‘UCFCrime2Local.zip’
#
# UCFCrime2Local.zip  100%[===================>] 515.34K   191KB/s    in 2.7s
#
# 2020-02-02 18:51:28 (191 KB/s) - ‘UCFCrime2Local.zip’ saved [527704/527704]
#
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 527704 bytes (516 KiB)
#
# Extracting archive: /content/UCFCrime2Local.zip
# --
# Path = /content/UCFCrime2Local.zip
# Type = zip
# Physical Size = 527704
#
#   0%
# ...

# %%
# !wget 'https://uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com/cd/0/get/AxUeJ1KliuUSjGti6nyO5rPLtouOy1ekmlxwY8X7kHWMROGo5qqpv1vuIV-rTRgdBujuFwjqZ41Hyx9oGyf5YQRXpb7_Zzy7juwxEXW1XpNGjw/file?_download_id=1653313608164150837883581475872942477953895523038523707127981834897&_notify_domain=www.dropbox.com&dl=1' -O'Temporal_Anomaly_Annotation_for_Testing_Videos.txt'
# Out:
# --2020-02-02 18:57:43--  https://uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com/cd/0/get/AxUeJ1KliuUSjGti6nyO5rPLtouOy1ekmlxwY8X7kHWMROGo5qqpv1vuIV-rTRgdBujuFwjqZ41Hyx9oGyf5YQRXpb7_Zzy7juwxEXW1XpNGjw/file?_download_id=1653313608164150837883581475872942477953895523038523707127981834897&_notify_domain=www.dropbox.com&dl=1
# Resolving uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com (uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com)... 162.125.8.6, 2620:100:601b:6::a27d:806
# Connecting to uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com (uc9304e73112325111c8dad2c825.dl.dropboxusercontent.com)|162.125.8.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15574 (15K) [application/binary]
# Saving to: ‘Temporal_Anomaly_Annotation_for_Testing_Videos.txt’
#
# Temporal_Anomaly_An 100%[===================>]  15.21K  --.-KB/s    in 0s
#
# ...

# %%
# !cp '/content/Temporal_Anomaly_Annotation_for_Testing_Videos.txt' '/content/drive/My Drive/Project'

# %%
import os
os.chdir('/content')
import pandas as pd
videos_names = pd.read_csv('/content/drive/My Drive/Project/UCFCrime2Local (Tube Extr.)/Videos_from_UCFCrime.txt', header=None)

# %%
videos_names[:6]
# Out:
#                     0
# 0  Arrest002_x264.mp4
# 1  Arrest003_x264.mp4
# 2  Arrest005_x264.mp4
# 3  Arrest006_x264.mp4
# 4  Arrest009_x264.mp4
# 5  Arrest022_x264.mp4

# %%
# !mkdir '/content/drive/My Drive/Project/AnomalyVideos'

# %%
# !cp -R '/content/drive/My Drive/Project/Anomaly-Videos-Part-1/Abuse' '/content/drive/My Drive/Project/AnomalyVideos'

# %%
import numpy as np

from tensorflow.python.keras import activations
from tensorflow.python.keras import backend as K
from tensorflow.python.keras import constraints
from tensorflow.python.keras import initializers
from tensorflow.python.keras import regularizers
from tensorflow.python.keras.engine.base_layer import Layer
from tensorflow.python.keras.engine.input_spec import InputSpec
from tensorflow.python.keras.layers.recurrent import _standardize_args
from tensorflow.python.keras.layers.recurrent import DropoutRNNCellMixin
from tensorflow.python.keras.layers.recurrent import RNN
from tensorflow.python.keras.utils import conv_utils
from tensorflow.python.keras.utils import generic_utils
from tensorflow.python.keras.utils import tf_utils
from tensorflow.python.ops import array_ops
from tensorflow.python.util.tf_export import keras_export


from keras.models import Model
from keras.layers import Input, Dense, MaxPooling2D, MaxPooling3D, Dropout, BatchNormalization, Flatten, Conv2D, Conv3D, AveragePooling3D, LSTM, Reshape
from keras import backend as K
from keras.callbacks import History

print("All libraries imported successfully")
# Out:
# All libraries imported successfully
# Using TensorFlow backend.

# %%
#ConvLSTM Model
def My_ConvLSTM_Model(frames, channels, pixels_x, pixels_y, categories):
  
    trailer_input  = Input(shape=(frames, channels, pixels_x, pixels_y)
                    , name='trailer_input')
    
    first_ConvLSTM = ConvLSTM2D(filters=20, kernel_size=(3, 3)
                       , data_format='channels_first'
                       , recurrent_activation='hard_sigmoid'
                       , activation='tanh'
                       , padding='same', return_sequences=True)(trailer_input)
    first_BatchNormalization = BatchNormalization()(first_ConvLSTM)
    first_Pooling = MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_first')(first_BatchNormalization)
    
    second_ConvLSTM = ConvLSTM2D(filters=10, kernel_size=(3, 3)
                        , data_format='channels_first'
                        , padding='same', return_sequences=True)(first_Pooling)
    second_BatchNormalization = BatchNormalization()(second_ConvLSTM)
    second_Pooling = MaxPooling3D(pool_size=(1, 3, 3), padding='same', data_format='channels_first')(second_BatchNormalization)
    
    outputs = [branch(second_Pooling, 'cat_{}'.format(category)) for category in categories]
    
    seq = Model(inputs=trailer_input, outputs=outputs, name='Model ')
    
    return seq

def branch(last_convlstm_layer, name):
  
    branch_ConvLSTM = ConvLSTM2D(filters=5, kernel_size=(3, 3)
                        , data_format='channels_first'
                        , stateful = False
                        , kernel_initializer='random_uniform'
                        , padding='same', return_sequences=True)(last_convlstm_layer)
    branch_Pooling = MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_first')(branch_ConvLSTM)
    flat_layer = TimeDistributed(Flatten())(branch_Pooling)
    
    first_Dense = TimeDistributed(Dense(512,))(flat_layer)
    second_Dense = TimeDistributed(Dense(32,))(first_Dense)
    
    target = TimeDistributed(Dense(1), name=name)(second_Dense)
    
    return target
